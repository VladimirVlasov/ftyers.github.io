# %%
from tqdm import tqdm
import pickle as p
from numpy import random
import re

class unigram_model():
    def __init__(self, file):
        self.freq_of_word = {}
        self.freq_of_word_tag = {}
        self.train(file)
        del self.freq_of_word
        
        
    def add_word(self, word, tag):
        if word not in self.freq_of_word:
            self.freq_of_word[word] = 0
            self.freq_of_word_tag[word] = {}
        if tag not in self.freq_of_word_tag[word]:
            self.freq_of_word_tag[word][tag] = 0
        self.freq_of_word[word] = self.freq_of_word[word] + 1
        self.freq_of_word_tag[word][tag] = self.freq_of_word_tag[word][tag] + 1
    
    def train(self, file):
        with open(file) as train_file:
            for line in tqdm(train_file):
                if line[0] in '1234567890':
                    splited = line.split('\t')
                    word = splited[1].lower()
                    tag = splited[3]
                    self.add_word(word, tag)
        self.finish_train()
    
    def finish_train(self):
        for word in self.freq_of_word:
            for tag in self.freq_of_word_tag[word]:
                self.freq_of_word_tag[word][tag] = self.freq_of_word_tag[word][tag] / self.freq_of_word[word]
                
    def predict_word(self, word):
        word = word.lower()
        if word in self.freq_of_word_tag:
            tags = []
            probs = []
            for tag, prob in self.freq_of_word_tag[word].items():
                tags.append(tag)
                probs.append(prob)
            return random.choice(tags, p=probs)
        else:
            return None
        
    def predict_for_line_with_stdout(self, line):
        print('#text = {}'.format(line))
        counter = 0
        for word in re.findall(r'[\w]+\b', line):
            counter += 1
            print('{}\t{}\t{}'.format(counter, word, self.predict_word(word)))
    
    def transform_file(self, file):
        with open(file) as input_file:
            for line in input_file:
                self.predict_for_line_with_stdout(line)

# %%
output = 'saved_model.p'
model = unigram_model('syntagrus.conllu')
with open(output, 'wb') as model_file:
    p.dump(model, model_file, protocol=p.HIGHEST_PROTOCOL)
# Out:
# 1017963it [00:02, 494386.60it/s]

# %%
model.transform_file('nightmare.txt')
# Out:
# #text = КОШМАР БОГОСЛОВА.
#
# 1	КОШМАР	NOUN
# 2	БОГОСЛОВА	None
# #text =
#
# #text =       Знаменитому богослову доктору Таддеусу как-то приснилось, что он умер и отправился на небеса. Весь путь он проделал без всяких трудностей, так как богословские занятия научили его запросто ориентироваться в небе. Когда же наконец он прибыл к месту и стал стучаться в небесные ворота, то был удивлен подозрительностью, с которой его встретили.
#
# 1	Знаменитому	ADJ
# 2	богослову	None
# 3	доктору	NOUN
# 4	Таддеусу	None
# 5	как	ADV
# 6	то	SCONJ
# 7	приснилось	VERB
# 8	что	SCONJ
# 9	он	PRON
# 10	умер	VERB
# 11	и	CCONJ
# 12	отправился	VERB
# 13	на	ADP
# 14	небеса	None
# 15	Весь	DET
# 16	путь	NOUN
# 17	он	PRON
# 18	проделал	VERB
# 19	без	ADP
# 20	всяких	DET
# 21	трудностей	NOUN
# 22	так	ADV
# 23	как	SCONJ
# 24	богословские	None
# 25	занятия	NOUN
# 26	научили	VERB
# 27	его	DET
# 28	запросто	ADV
# 29	ориентироваться	VERB
# 30	в	ADP
# 31	небе	NOUN
# 32	Когда	SCONJ
# 33	же	PART
# 34	наконец	ADV
# 35	он	PRON
# 36	прибыл	VERB
# 37	к	ADP
# 38	месту	NOUN
# 39	и	CCONJ
# 40	стал	VERB
# 41	стучаться	VERB
# 42	в	ADP
# 43	небесные	None
# 44	ворота	NOUN
# 45	то	SCONJ
# 46	был	AUX
# 47	удивлен	ADJ
# 48	подозрительностью	None
# 49	с	ADP
# 50	которой	PRON
# 51	его	PRON
# 52	встретили	VERB
# #text =       - Прошу впустить меня,- обратился он к привратнику.- Я благонамеренный человек и всю свою жизнь посвятил трудам во славу божью.
#
# 1	Прошу	VERB
# 2	впустить	VERB
# 3	меня	PRON
# 4	обратился	VERB
# 5	он	PRON
# 6	к	ADP
# 7	привратнику	None
# 8	Я	PRON
# 9	благонамеренный	None
# 10	человек	PROPN
# 11	и	CCONJ
# 12	всю	DET
# 13	свою	DET
# 14	жизнь	NOUN
# 15	посвятил	VERB
# 16	трудам	NOUN
# 17	во	ADP
# 18	славу	NOUN
# 19	божью	ADJ
# #text =       - Человек? - удивленно переспросил привратник.- А что это такое? И потом, как может такое странное, я бы сказал, потешное существо, как вы, поддерживать чем-либо славу божью?
#
# 1	Человек	NOUN
# 2	удивленно	None
# 3	переспросил	None
# 4	привратник	None
# 5	А	CCONJ
# 6	что	PRON
# 7	это	PRON
# 8	такое	DET
# 9	И	CCONJ
# 10	потом	ADV
# 11	как	ADV
# 12	может	VERB
# 13	такое	DET
# 14	странное	ADJ
# 15	я	PRON
# 16	бы	PART
# 17	сказал	VERB
# 18	потешное	None
# 19	существо	NOUN
# 20	как	ADV
# 21	вы	PRON
# 22	поддерживать	VERB
# 23	чем	SCONJ
# 24	либо	CCONJ
# 25	славу	NOUN
# 26	божью	ADJ
# #text =       Доктор Таддеус был поражен.
#
# 1	Доктор	NOUN
# 2	Таддеус	None
# 3	был	AUX
# 4	поражен	VERB
# #text =       - Вы не можете не знать о человеке,- настаивал он.- Вам должно быть известно, что человек - это высшее творение создателя.
#
# 1	Вы	PRON
# 2	не	PART
# 3	можете	VERB
# 4	не	PART
# 5	знать	VERB
# 6	о	ADP
# 7	человеке	NOUN
# 8	настаивал	VERB
# 9	он	PRON
# 10	Вам	PRON
# 11	должно	ADJ
# 12	быть	AUX
# 13	известно	ADJ
# 14	что	SCONJ
# 15	человек	NOUN
# 16	это	PRON
# 17	высшее	ADJ
# 18	творение	None
# 19	создателя	NOUN
# #text =       - Мне очень не хочется обидеть вас,- сказал привратник,- но то, что вы говорите, совершенная новость для меня. И я сомневаюсь, слыхал ли кто-либо у нас здесь о таком существе. Однако, раз вы так настаиваете, я позову нашего библиотекаря, и вы можете справиться у него.
#
# 1	Мне	PRON
# 2	очень	ADV
# 3	не	PART
# 4	хочется	VERB
# 5	обидеть	VERB
# 6	вас	PRON
# 7	сказал	VERB
# 8	привратник	None
# 9	но	CCONJ
# 10	то	PRON
# 11	что	SCONJ
# 12	вы	PRON
# 13	говорите	VERB
# 14	совершенная	ADJ
# 15	новость	NOUN
# 16	для	ADP
# 17	меня	PRON
# 18	И	CCONJ
# 19	я	PRON
# 20	сомневаюсь	VERB
# 21	слыхал	None
# 22	ли	PART
# 23	кто	PRON
# 24	либо	CCONJ
# 25	у	ADP
# 26	нас	PRON
# 27	здесь	ADV
# 28	о	ADP
# 29	таком	DET
# 30	существе	NOUN
# 31	Однако	ADV
# 32	раз	NOUN
# 33	вы	PRON
# 34	так	ADV
# 35	настаиваете	None
# 36	я	PRON
# 37	позову	None
# 38	нашего	DET
# 39	библиотекаря	None
# 40	и	CCONJ
# 41	вы	PRON
# 42	можете	VERB
# 43	справиться	VERB
# 44	у	ADP
# 45	него	PRON
# #text =       Появившийся вскоре библиотекарь оказался большим шаровидным существом, у которого было не менее тысячи глаз и один-единственный рот. Несколькими десятками глаз он уставился на знаменитого богослова.
#
# 1	Появившийся	VERB
# 2	вскоре	ADV
# 3	библиотекарь	None
# 4	оказался	VERB
# 5	большим	ADJ
# 6	шаровидным	None
# 7	существом	NOUN
# 8	у	ADP
# 9	которого	PRON
# 10	было	VERB
# 11	не	PART
# 12	менее	ADV
# 13	тысячи	NOUN
# 14	глаз	NOUN
# 15	и	CCONJ
# 16	один	NUM
# 17	единственный	ADJ
# 18	рот	NOUN
# 19	Несколькими	NUM
# 20	десятками	NOUN
# 21	глаз	NOUN
# 22	он	PRON
# 23	уставился	None
# 24	на	ADP
# 25	знаменитого	ADJ
# 26	богослова	None
# #text =       - Что это? - спросил он у привратника.
#
# 1	Что	SCONJ
# 2	это	PRON
# 3	спросил	VERB
# 4	он	PRON
# 5	у	ADP
# 6	привратника	None
# #text =       - Да вот прибыл к нам и заявляет,- пояснил привратник,- что он из породы, которая называется человек, и живет в месте, называемом Земля. При этом у него какие-то странные представления. Он утверждает, будто создатель проявил особый интерес к их месту и к их породе.
#
# 1	Да	CCONJ
# 2	вот	PART
# 3	прибыл	VERB
# 4	к	ADP
# 5	нам	PRON
# 6	и	CCONJ
# 7	заявляет	VERB
# 8	пояснил	VERB
# 9	привратник	None
# 10	что	PRON
# 11	он	PRON
# 12	из	ADP
# 13	породы	NOUN
# 14	которая	PRON
# 15	называется	VERB
# 16	человек	NOUN
# 17	и	PART
# 18	живет	VERB
# 19	в	ADP
# 20	месте	NOUN
# 21	называемом	VERB
# 22	Земля	PROPN
# 23	При	ADP
# 24	этом	DET
# 25	у	ADP
# 26	него	PRON
# 27	какие	DET
# 28	то	SCONJ
# 29	странные	ADJ
# 30	представления	NOUN
# 31	Он	PRON
# 32	утверждает	VERB
# 33	будто	PART
# 34	создатель	None
# 35	проявил	VERB
# 36	особый	ADJ
# 37	интерес	NOUN
# 38	к	ADP
# 39	их	PRON
# 40	месту	NOUN
# 41	и	CCONJ
# 42	к	ADP
# 43	их	PRON
# 44	породе	NOUN
# #text =       Я подумал, быть может, вы что-нибудь знаете об этом?
#
# 1	Я	PRON
# 2	подумал	VERB
# 3	быть	AUX
# 4	может	VERB
# 5	вы	PRON
# 6	что	SCONJ
# 7	нибудь	None
# 8	знаете	VERB
# 9	об	ADP
# 10	этом	PRON
# #text =       - Вы не могли бы объяснить мне, где находится то место, которое вы называете Землей? - весьма любезно обратился библиотекарь к богослову.
#
# 1	Вы	PRON
# 2	не	PART
# 3	могли	VERB
# 4	бы	PART
# 5	объяснить	VERB
# 6	мне	PRON
# 7	где	ADV
# 8	находится	VERB
# 9	то	SCONJ
# 10	место	NOUN
# 11	которое	PRON
# 12	вы	PRON
# 13	называете	VERB
# 14	Землей	NOUN
# 15	весьма	ADV
# 16	любезно	None
# 17	обратился	VERB
# 18	библиотекарь	None
# 19	к	ADP
# 20	богослову	None
# #text =       - О,- воскликнул д-р Таддеус,- это же часть Солнечной системы!
#
# 1	О	ADP
# 2	воскликнул	VERB
# 3	д	ADV
# 4	р	NOUN
# 5	Таддеус	None
# 6	это	PRON
# 7	же	PART
# 8	часть	NOUN
# 9	Солнечной	ADJ
# 10	системы	NOUN
# #text =       - А что такое Солнечная система? - спросил библиотекарь.
#
# 1	А	CCONJ
# 2	что	SCONJ
# 3	такое	DET
# 4	Солнечная	ADJ
# 5	система	NOUN
# 6	спросил	VERB
# 7	библиотекарь	None
# #text =       - Ох,- несколько смущенно сказал д-р Таддеус,- моя область - Священное писание, а то, о чем вы спрашиваете, относится к мирским наукам. Однако от моих друзей, сведущих в астрономии, я слышал, что Солнечная система - это часть Млечного Пути.
#
# 1	Ох	PROPN
# 2	несколько	NUM
# 3	смущенно	ADV
# 4	сказал	VERB
# 5	д	ADV
# 6	р	PROPN
# 7	Таддеус	None
# 8	моя	DET
# 9	область	NOUN
# 10	Священное	ADJ
# 11	писание	PROPN
# 12	а	CCONJ
# 13	то	SCONJ
# 14	о	ADP
# 15	чем	SCONJ
# 16	вы	PRON
# 17	спрашиваете	None
# 18	относится	VERB
# 19	к	ADP
# 20	мирским	None
# 21	наукам	NOUN
# 22	Однако	ADV
# 23	от	ADP
# 24	моих	DET
# 25	друзей	NOUN
# 26	сведущих	None
# 27	в	ADP
# 28	астрономии	NOUN
# 29	я	PRON
# 30	слышал	VERB
# 31	что	PRON
# 32	Солнечная	ADJ
# 33	система	NOUN
# 34	это	PRON
# 35	часть	NOUN
# 36	Млечного	None
# 37	Пути	NOUN
# #text =       - А что такое Млечный Путь? - тут же спросил библиотекарь.
#
# 1	А	CCONJ
# 2	что	SCONJ
# 3	такое	DET
# 4	Млечный	None
# 5	Путь	NOUN
# 6	тут	ADV
# 7	же	PART
# 8	спросил	VERB
# 9	библиотекарь	None
# #text =       - Млечный Путь - это одна из галактик, которых, как мне говорили, насчитывается что-то около ста миллионов.
#
# 1	Млечный	None
# 2	Путь	NOUN
# 3	это	PRON
# 4	одна	NUM
# 5	из	ADP
# 6	галактик	NOUN
# 7	которых	PRON
# 8	как	SCONJ
# 9	мне	PRON
# 10	говорили	VERB
# 11	насчитывается	VERB
# 12	что	SCONJ
# 13	то	PRON
# 14	около	ADP
# 15	ста	NUM
# 16	миллионов	NOUN
# #text =       - Раз их так много,- сказал библиотекарь,- то странно, что вы могли предположить, чтобы я помнил об одной из них. Но я припоминаю, что само слово "галактика" мне приходилось слышать. Действительно, среди наших помощников библиотекарей есть один, который специально занимается галактиками. Надо послать за ним, и, может быть, он сумеет помочь нам.
#
# 1	Раз	NOUN
# 2	их	PRON
# 3	так	ADV
# 4	много	ADV
# 5	сказал	VERB
# 6	библиотекарь	None
# 7	то	PRON
# 8	странно	ADV
# 9	что	SCONJ
# 10	вы	PRON
# 11	могли	VERB
# 12	предположить	VERB
# 13	чтобы	SCONJ
# 14	я	PRON
# 15	помнил	VERB
# 16	об	ADP
# 17	одной	NUM
# 18	из	ADP
# 19	них	PRON
# 20	Но	CCONJ
# 21	я	PRON
# 22	припоминаю	VERB
# 23	что	PRON
# 24	само	ADJ
# 25	слово	NOUN
# 26	галактика	None
# 27	мне	PRON
# 28	приходилось	VERB
# 29	слышать	VERB
# 30	Действительно	ADV
# 31	среди	ADP
# 32	наших	DET
# 33	помощников	NOUN
# 34	библиотекарей	None
# 35	есть	AUX
# 36	один	NUM
# 37	который	PRON
# 38	специально	ADV
# 39	занимается	VERB
# 40	галактиками	None
# 41	Надо	ADV
# 42	послать	VERB
# 43	за	ADP
# 44	ним	PRON
# 45	и	CCONJ
# 46	может	VERB
# 47	быть	AUX
# 48	он	PRON
# 49	сумеет	VERB
# 50	помочь	VERB
# 51	нам	PRON
# #text =       После недолгого ожидания появился помощник библиотекаря, занимающийся галактиками. Это было существо в виде двенадцатигранника. Когда-то оно было светлым и блестящим, но пыль с книжных полок, постоянно оседавшая на нем, сделала его тусклым и мрачным. Библиотекарь подробно рассказал ему, что вот прибывший к ним д-р Таддеус, пытаясь объяснить свое происхождение, упоминает галактики, и в связи с этим хотелось бы надеяться, что надлежащая информация может быть получена от секции библиотеки, занимающейся этим вопросом.
#
# 1	После	ADP
# 2	недолгого	ADJ
# 3	ожидания	NOUN
# 4	появился	VERB
# 5	помощник	NOUN
# 6	библиотекаря	None
# 7	занимающийся	VERB
# 8	галактиками	None
# 9	Это	PRON
# 10	было	AUX
# 11	существо	NOUN
# 12	в	ADP
# 13	виде	NOUN
# 14	двенадцатигранника	None
# 15	Когда	SCONJ
# 16	то	DET
# 17	оно	PRON
# 18	было	AUX
# 19	светлым	ADJ
# 20	и	CCONJ
# 21	блестящим	ADJ
# 22	но	CCONJ
# 23	пыль	NOUN
# 24	с	ADP
# 25	книжных	ADJ
# 26	полок	None
# 27	постоянно	ADV
# 28	оседавшая	None
# 29	на	ADP
# 30	нем	PRON
# 31	сделала	VERB
# 32	его	DET
# 33	тусклым	ADJ
# 34	и	CCONJ
# 35	мрачным	None
# 36	Библиотекарь	None
# 37	подробно	ADV
# 38	рассказал	VERB
# 39	ему	PRON
# 40	что	PRON
# 41	вот	PART
# 42	прибывший	VERB
# 43	к	ADP
# 44	ним	PRON
# 45	д	ADV
# 46	р	NOUN
# 47	Таддеус	None
# 48	пытаясь	VERB
# 49	объяснить	VERB
# 50	свое	DET
# 51	происхождение	NOUN
# 52	упоминает	VERB
# 53	галактики	PROPN
# 54	и	CCONJ
# 55	в	ADP
# 56	связи	NOUN
# 57	с	ADP
# 58	этим	DET
# 59	хотелось	VERB
# 60	бы	PART
# 61	надеяться	VERB
# 62	что	SCONJ
# 63	надлежащая	None
# 64	информация	NOUN
# 65	может	VERB
# 66	быть	AUX
# 67	получена	VERB
# 68	от	ADP
# 69	секции	NOUN
# 70	библиотеки	NOUN
# 71	занимающейся	VERB
# 72	этим	DET
# 73	вопросом	NOUN
# #text =       - Все, что можно, будет сделано,- ответил помощник библиотекаря.- Однако прошу иметь в виду, что существует сто миллионов галактик и о каждой на полке стоит один том. Поэтому потребуется некоторое время, чтобы получить нужную справку. А какую именно галактику просит найти эта странная молекула?
#
# 1	Все	DET
# 2	что	SCONJ
# 3	можно	ADV
# 4	будет	VERB
# 5	сделано	VERB
# 6	ответил	VERB
# 7	помощник	NOUN
# 8	библиотекаря	None
# 9	Однако	ADV
# 10	прошу	VERB
# 11	иметь	VERB
# 12	в	ADP
# 13	виду	NOUN
# 14	что	SCONJ
# 15	существует	VERB
# 16	сто	NUM
# 17	миллионов	NOUN
# 18	галактик	NOUN
# 19	и	PART
# 20	о	ADP
# 21	каждой	DET
# 22	на	ADP
# 23	полке	NOUN
# 24	стоит	VERB
# 25	один	NUM
# 26	том	PRON
# 27	Поэтому	ADV
# 28	потребуется	VERB
# 29	некоторое	DET
# 30	время	NOUN
# 31	чтобы	SCONJ
# 32	получить	VERB
# 33	нужную	ADJ
# 34	справку	NOUN
# 35	А	CCONJ
# 36	какую	DET
# 37	именно	PART
# 38	галактику	None
# 39	просит	VERB
# 40	найти	VERB
# 41	эта	DET
# 42	странная	ADJ
# 43	молекула	NOUN
# #text =       - Она часть Млечного Пути,- заискивающе пояснил д-р Таддеус.
#
# 1	Она	PRON
# 2	часть	NOUN
# 3	Млечного	None
# 4	Пути	NOUN
# 5	заискивающе	None
# 6	пояснил	VERB
# 7	д	ADV
# 8	р	NOUN
# 9	Таддеус	None
# #text =       - Хорошо,- сказал помощник библиотекаря,- я постараюсь найти ее.
#
# 1	Хорошо	ADJ
# 2	сказал	VERB
# 3	помощник	NOUN
# 4	библиотекаря	None
# 5	я	PRON
# 6	постараюсь	VERB
# 7	найти	VERB
# 8	ее	DET
# #text =       Через три недели помощник библиотекаря вернулся и сообщил, что только благодаря тому, что в их секции имеется исключительно полная, хорошо составленная картотека, они смогли наконец разыскать требующуюся галактику под номером XO 321762.
#
# 1	Через	ADP
# 2	три	NUM
# 3	недели	NOUN
# 4	помощник	NOUN
# 5	библиотекаря	None
# 6	вернулся	VERB
# 7	и	CCONJ
# 8	сообщил	VERB
# 9	что	SCONJ
# 10	только	PART
# 11	благодаря	ADP
# 12	тому	PRON
# 13	что	SCONJ
# 14	в	ADP
# 15	их	PRON
# 16	секции	NOUN
# 17	имеется	VERB
# 18	исключительно	ADV
# 19	полная	ADJ
# 20	хорошо	ADV
# 21	составленная	VERB
# 22	картотека	None
# 23	они	PRON
# 24	смогли	VERB
# 25	наконец	ADV
# 26	разыскать	None
# 27	требующуюся	None
# 28	галактику	None
# 29	под	ADP
# 30	номером	NOUN
# 31	XO	None
# 32	321762	None
# #text =       - Все пять тысяч клерков секции галактик занимались этой работой,- добавил помощник библиотекаря и предложил: - Может быть, вы хотели бы переговорить с тем клерком, который отыскал эту галактику и специально занимался ею?
#
# 1	Все	PART
# 2	пять	NUM
# 3	тысяч	NOUN
# 4	клерков	NOUN
# 5	секции	NOUN
# 6	галактик	NOUN
# 7	занимались	VERB
# 8	этой	DET
# 9	работой	NOUN
# 10	добавил	VERB
# 11	помощник	NOUN
# 12	библиотекаря	None
# 13	и	PART
# 14	предложил	VERB
# 15	Может	VERB
# 16	быть	VERB
# 17	вы	PRON
# 18	хотели	VERB
# 19	бы	PART
# 20	переговорить	None
# 21	с	ADP
# 22	тем	PRON
# 23	клерком	NOUN
# 24	который	PRON
# 25	отыскал	VERB
# 26	эту	DET
# 27	галактику	None
# 28	и	CCONJ
# 29	специально	ADV
# 30	занимался	VERB
# 31	ею	PRON
# #text =       Послали за клерком, и вскоре к ним вышел восьмигранник, у которого на каждой грани было по одному глазу и всего лишь один небольшой рот. У него был смущенный вид, он щурился от непривычно яркого света, так как обычно всегда находился в мрачной полутьме своих книжных полок. Овладев собой, он обратился к д-ру Таддеусу:
#
# 1	Послали	VERB
# 2	за	ADP
# 3	клерком	NOUN
# 4	и	CCONJ
# 5	вскоре	ADV
# 6	к	ADP
# 7	ним	PRON
# 8	вышел	VERB
# 9	восьмигранник	None
# 10	у	ADP
# 11	которого	PRON
# 12	на	ADP
# 13	каждой	DET
# 14	грани	NOUN
# 15	было	AUX
# 16	по	ADP
# 17	одному	NUM
# 18	глазу	NOUN
# 19	и	CCONJ
# 20	всего	DET
# 21	лишь	PART
# 22	один	NUM
# 23	небольшой	ADJ
# 24	рот	NOUN
# 25	У	ADP
# 26	него	PRON
# 27	был	AUX
# 28	смущенный	ADJ
# 29	вид	NOUN
# 30	он	PRON
# 31	щурился	VERB
# 32	от	ADP
# 33	непривычно	ADJ
# 34	яркого	ADJ
# 35	света	NOUN
# 36	так	ADV
# 37	как	SCONJ
# 38	обычно	ADV
# 39	всегда	ADV
# 40	находился	VERB
# 41	в	ADP
# 42	мрачной	ADJ
# 43	полутьме	None
# 44	своих	DET
# 45	книжных	ADJ
# 46	полок	None
# 47	Овладев	VERB
# 48	собой	PRON
# 49	он	PRON
# 50	обратился	VERB
# 51	к	ADP
# 52	д	ADV
# 53	ру	PROPN
# 54	Таддеусу	None
# #text =       - Что вы хотите знать об этой галактике? - довольно робко спросил он.
#
# 1	Что	SCONJ
# 2	вы	PRON
# 3	хотите	VERB
# 4	знать	VERB
# 5	об	ADP
# 6	этой	DET
# 7	галактике	PROPN
# 8	довольно	ADV
# 9	робко	ADV
# 10	спросил	VERB
# 11	он	PRON
# #text =       - Мне бы хотелось знать, что вам известно о Солнечной системе,- громко и самоуверенно заговорил д-р Таддеус.- Она как раз находится в той галактике, что вы нашли, и в ней небесные тела вращаются вокруг одной звезды, которая называется Солнце.
#
# 1	Мне	PRON
# 2	бы	PART
# 3	хотелось	VERB
# 4	знать	VERB
# 5	что	PRON
# 6	вам	PRON
# 7	известно	ADJ
# 8	о	ADP
# 9	Солнечной	ADJ
# 10	системе	NOUN
# 11	громко	ADV
# 12	и	CCONJ
# 13	самоуверенно	None
# 14	заговорил	VERB
# 15	д	ADV
# 16	р	NOUN
# 17	Таддеус	None
# 18	Она	PRON
# 19	как	SCONJ
# 20	раз	NOUN
# 21	находится	VERB
# 22	в	ADP
# 23	той	DET
# 24	галактике	PROPN
# 25	что	SCONJ
# 26	вы	PRON
# 27	нашли	VERB
# 28	и	CCONJ
# 29	в	ADP
# 30	ней	PRON
# 31	небесные	None
# 32	тела	NOUN
# 33	вращаются	VERB
# 34	вокруг	ADP
# 35	одной	NUM
# 36	звезды	NOUN
# 37	которая	PRON
# 38	называется	VERB
# 39	Солнце	PROPN
# #text =       - Гм! - пробормотал клерк.- Было весьма трудно отыскать одну из миллионов галактик, но несравненно труднее найти какую-либо звезду в этой галактике. Я знаю, что в ней около трехсот миллиардов звезд, но как их различать одну от другой, я не знаю. Мне известно, однако, что по указанию нашей администрации были как-то составлены списки всех этих трехсот миллиардов звезд, и они хранятся в подвалах. Если вы считаете, что стоит заняться поиском звезды, которая называется Солнцем, то для этого придется привлечь значительное количество сотрудников из других отделов.
#
# 1	Гм	None
# 2	пробормотал	VERB
# 3	клерк	NOUN
# 4	Было	AUX
# 5	весьма	ADV
# 6	трудно	ADJ
# 7	отыскать	VERB
# 8	одну	NUM
# 9	из	ADP
# 10	миллионов	NOUN
# 11	галактик	NOUN
# 12	но	CCONJ
# 13	несравненно	ADV
# 14	труднее	ADJ
# 15	найти	VERB
# 16	какую	DET
# 17	либо	CCONJ
# 18	звезду	NOUN
# 19	в	ADP
# 20	этой	DET
# 21	галактике	PROPN
# 22	Я	PRON
# 23	знаю	VERB
# 24	что	SCONJ
# 25	в	ADP
# 26	ней	PRON
# 27	около	ADP
# 28	трехсот	NUM
# 29	миллиардов	NOUN
# 30	звезд	NOUN
# 31	но	CCONJ
# 32	как	SCONJ
# 33	их	DET
# 34	различать	VERB
# 35	одну	NUM
# 36	от	ADP
# 37	другой	ADJ
# 38	я	PRON
# 39	не	PART
# 40	знаю	VERB
# 41	Мне	PRON
# 42	известно	ADJ
# 43	однако	ADV
# 44	что	SCONJ
# 45	по	ADP
# 46	указанию	NOUN
# 47	нашей	DET
# 48	администрации	NOUN
# 49	были	AUX
# 50	как	SCONJ
# 51	то	PRON
# 52	составлены	None
# 53	списки	NOUN
# 54	всех	DET
# 55	этих	DET
# 56	трехсот	NUM
# 57	миллиардов	NOUN
# 58	звезд	NOUN
# 59	и	CCONJ
# 60	они	PRON
# 61	хранятся	VERB
# 62	в	ADP
# 63	подвалах	NOUN
# 64	Если	SCONJ
# 65	вы	PRON
# 66	считаете	VERB
# 67	что	SCONJ
# 68	стоит	VERB
# 69	заняться	VERB
# 70	поиском	NOUN
# 71	звезды	NOUN
# 72	которая	PRON
# 73	называется	VERB
# 74	Солнцем	NOUN
# 75	то	SCONJ
# 76	для	ADP
# 77	этого	DET
# 78	придется	VERB
# 79	привлечь	VERB
# 80	значительное	ADJ
# 81	количество	NOUN
# 82	сотрудников	NOUN
# 83	из	ADP
# 84	других	ADJ
# 85	отделов	NOUN
# #text =       В конце концов решили, что, поскольку вопрос уже возник, а прибывший д-р Таддеус находится в беспокойном состоянии и очень мучится, поиски звезды, которая называется Солнцем, следует предпринять.
#
# 1	В	ADP
# 2	конце	NOUN
# 3	концов	NOUN
# 4	решили	VERB
# 5	что	SCONJ
# 6	поскольку	SCONJ
# 7	вопрос	NOUN
# 8	уже	ADV
# 9	возник	VERB
# 10	а	CCONJ
# 11	прибывший	VERB
# 12	д	ADV
# 13	р	NOUN
# 14	Таддеус	None
# 15	находится	VERB
# 16	в	ADP
# 17	беспокойном	None
# 18	состоянии	NOUN
# 19	и	CCONJ
# 20	очень	ADV
# 21	мучится	None
# 22	поиски	NOUN
# 23	звезды	NOUN
# 24	которая	PRON
# 25	называется	VERB
# 26	Солнцем	PROPN
# 27	следует	VERB
# 28	предпринять	VERB
# #text =       Через несколько лет сильно утомленный, унылого вида четырехгранник явился к помощнику библиотекаря, ведающему секцией галактик.
#
# 1	Через	ADP
# 2	несколько	NUM
# 3	лет	NOUN
# 4	сильно	ADV
# 5	утомленный	VERB
# 6	унылого	ADJ
# 7	вида	NOUN
# 8	четырехгранник	None
# 9	явился	VERB
# 10	к	ADP
# 11	помощнику	None
# 12	библиотекаря	None
# 13	ведающему	None
# 14	секцией	None
# 15	галактик	NOUN
# #text =       - Мне удалось отыскать звезду, которая называется Солнце,- сказал он.- Но я совершенно не могу понять, чем вызван такой особый интерес к ней. Она такая же, как и большинство других звезд в этой галактике.
#
# 1	Мне	PRON
# 2	удалось	VERB
# 3	отыскать	VERB
# 4	звезду	NOUN
# 5	которая	PRON
# 6	называется	VERB
# 7	Солнце	NOUN
# 8	сказал	VERB
# 9	он	PRON
# 10	Но	CCONJ
# 11	я	PRON
# 12	совершенно	ADV
# 13	не	PART
# 14	могу	VERB
# 15	понять	VERB
# 16	чем	SCONJ
# 17	вызван	VERB
# 18	такой	DET
# 19	особый	ADJ
# 20	интерес	NOUN
# 21	к	ADP
# 22	ней	PRON
# 23	Она	PRON
# 24	такая	DET
# 25	же	PART
# 26	как	SCONJ
# 27	и	PART
# 28	большинство	NOUN
# 29	других	ADJ
# 30	звезд	NOUN
# 31	в	ADP
# 32	этой	DET
# 33	галактике	PROPN
# #text =       Среднего размера, со средней температурой и окружена небольшими телами, их называют "планеты". В результате исследования я обнаружил, что на некоторых планетах имеются микроорганизмы, и думаю, что вот это прибывшее к нам существо, толкнувшее нас на эти поиски, должно быть, одно из них.
#
# 1	Среднего	ADJ
# 2	размера	NOUN
# 3	со	ADP
# 4	средней	ADJ
# 5	температурой	NOUN
# 6	и	PART
# 7	окружена	None
# 8	небольшими	ADJ
# 9	телами	NOUN
# 10	их	PRON
# 11	называют	VERB
# 12	планеты	NOUN
# 13	В	ADP
# 14	результате	NOUN
# 15	исследования	NOUN
# 16	я	PRON
# 17	обнаружил	VERB
# 18	что	PRON
# 19	на	ADP
# 20	некоторых	DET
# 21	планетах	NOUN
# 22	имеются	VERB
# 23	микроорганизмы	NOUN
# 24	и	PART
# 25	думаю	VERB
# 26	что	SCONJ
# 27	вот	PART
# 28	это	PRON
# 29	прибывшее	None
# 30	к	ADP
# 31	нам	PRON
# 32	существо	NOUN
# 33	толкнувшее	None
# 34	нас	PRON
# 35	на	ADP
# 36	эти	DET
# 37	поиски	NOUN
# 38	должно	ADJ
# 39	быть	AUX
# 40	одно	DET
# 41	из	ADP
# 42	них	PRON
# #text =       В этом месте д-р Таддеус не выдержал и разразился горькими и негодующими сетованиями.
#
# 1	В	ADP
# 2	этом	DET
# 3	месте	NOUN
# 4	д	ADV
# 5	р	NOUN
# 6	Таддеус	None
# 7	не	PART
# 8	выдержал	VERB
# 9	и	CCONJ
# 10	разразился	VERB
# 11	горькими	None
# 12	и	CCONJ
# 13	негодующими	None
# 14	сетованиями	None
# #text =       - Почему, ох, почему,- восклицал он,- создатель скрыл от нас, бедных обитателей Земли, что он создал без нашего ведома огромное множество других небес?! Всю свою долгую жизнь я усердно служил ему, веря, что он заметит мою службу и вознаградит меня вечным блаженством. А теперь оказывается, что он даже и не подозревал о моем существовании. И к тому же вы заявляете, что я какое-то бесконечно малое микроскопическое существо, обитающее на крошечной планете, вращающейся вокруг одной из незначительных звезд, которых только в нашей Галактике насчитывается триста миллиардов. Нет, я не могу вынести этого и не могу больше восхвалять моего создателя.
#
# 1	Почему	ADV
# 2	ох	INTJ
# 3	почему	ADV
# 4	восклицал	None
# 5	он	PRON
# 6	создатель	None
# 7	скрыл	VERB
# 8	от	ADP
# 9	нас	PRON
# 10	бедных	ADJ
# 11	обитателей	NOUN
# 12	Земли	PROPN
# 13	что	PRON
# 14	он	PRON
# 15	создал	VERB
# 16	без	ADP
# 17	нашего	DET
# 18	ведома	NOUN
# 19	огромное	ADJ
# 20	множество	NOUN
# 21	других	ADJ
# 22	небес	NOUN
# 23	Всю	DET
# 24	свою	DET
# 25	долгую	ADJ
# 26	жизнь	NOUN
# 27	я	PRON
# 28	усердно	None
# 29	служил	VERB
# 30	ему	PRON
# 31	веря	VERB
# 32	что	PRON
# 33	он	PRON
# 34	заметит	VERB
# 35	мою	DET
# 36	службу	NOUN
# 37	и	CCONJ
# 38	вознаградит	None
# 39	меня	PRON
# 40	вечным	ADJ
# 41	блаженством	None
# 42	А	CCONJ
# 43	теперь	ADV
# 44	оказывается	VERB
# 45	что	SCONJ
# 46	он	PRON
# 47	даже	PART
# 48	и	PART
# 49	не	PART
# 50	подозревал	VERB
# 51	о	ADP
# 52	моем	DET
# 53	существовании	NOUN
# 54	И	PART
# 55	к	ADP
# 56	тому	PRON
# 57	же	PART
# 58	вы	PRON
# 59	заявляете	None
# 60	что	PRON
# 61	я	PRON
# 62	какое	DET
# 63	то	SCONJ
# 64	бесконечно	ADV
# 65	малое	ADJ
# 66	микроскопическое	None
# 67	существо	NOUN
# 68	обитающее	None
# 69	на	ADP
# 70	крошечной	ADJ
# 71	планете	NOUN
# 72	вращающейся	VERB
# 73	вокруг	ADP
# 74	одной	NUM
# 75	из	ADP
# 76	незначительных	ADJ
# 77	звезд	NOUN
# 78	которых	PRON
# 79	только	PART
# 80	в	ADP
# 81	нашей	DET
# 82	Галактике	PROPN
# 83	насчитывается	VERB
# 84	триста	NUM
# 85	миллиардов	NOUN
# 86	Нет	VERB
# 87	я	PRON
# 88	не	PART
# 89	могу	VERB
# 90	вынести	VERB
# 91	этого	PRON
# 92	и	CCONJ
# 93	не	PART
# 94	могу	VERB
# 95	больше	ADV
# 96	восхвалять	VERB
# 97	моего	DET
# 98	создателя	NOUN
# #text =       - Очень хорошо,- сказал привратник.- В таком случае вам следует отправиться в другое место. И тут знаменитый богослов проснулся.
#
# 1	Очень	ADV
# 2	хорошо	ADJ
# 3	сказал	VERB
# 4	привратник	None
# 5	В	ADP
# 6	таком	DET
# 7	случае	NOUN
# 8	вам	PRON
# 9	следует	VERB
# 10	отправиться	VERB
# 11	в	ADP
# 12	другое	ADJ
# 13	место	NOUN
# 14	И	PART
# 15	тут	ADV
# 16	знаменитый	ADJ
# 17	богослов	None
# 18	проснулся	VERB
# #text =       - Власть дьявола над нашими сновидениями поистине ужасна,- в большом смущении пробормотал он.
#
# 1	Власть	NOUN
# 2	дьявола	NOUN
# 3	над	ADP
# 4	нашими	DET
# 5	сновидениями	None
# 6	поистине	ADV
# 7	ужасна	None
# 8	в	ADP
# 9	большом	ADJ
# 10	смущении	None
# 11	пробормотал	VERB
# 12	он	PRON
